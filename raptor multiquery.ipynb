# %% [markdown]
# # RAPTOR: Recursive Abstractive Processing for Tree-Organized Retrieval
#
# This notebook shows how to use an implementation of RAPTOR with llama-index, leveraging the RAPTOR llama-pack.
#
# RAPTOR works by recursively clustering and summarizing clusters in layers for retrieval.
#
# There two retrieval modes:
# - tree_traversal -- traversing the tree of clusters, performing top-k at each level in the tree.
# - collapsed -- treat the entire tree as a giant pile of nodes, perform simple top-k.
#
# See [the paper](https://arxiv.org/abs/2401.18059) for full algorithm details.

# %% [markdown]
# ## Setup

# %%
# !pip install llama-index llama-index-packs-raptor llama-index-vector-stores-qdrant chromadb  llama-index-vector-stores-chroma
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama-index in /home/harish/.local/lib/python3.10/site-packages (0.10.9)
# Requirement already satisfied: llama-index-packs-raptor in /home/harish/.local/lib/python3.10/site-packages (0.1.3)
# Requirement already satisfied: llama-index-vector-stores-qdrant in /home/harish/.local/lib/python3.10/site-packages (0.2.8)
# Requirement already satisfied: chromadb in /home/harish/.local/lib/python3.10/site-packages (0.4.24)
# Collecting llama-index-vector-stores-chroma
#   Downloading llama_index_vector_stores_chroma-0.1.8-py3-none-any.whl (4.8 kB)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: llama-index-readers-llama-parse<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.12)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.1)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.8.post1 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.10.20.post2)
# Requirement already satisfied: llama-index-agent-openai<0.2.0,>=0.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.1.5)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /home/harish/.local/lib/python3.10/site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: umap-learn>=0.5.5 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-packs-raptor) (0.5.6)
# Requirement already satisfied: scikit-learn in /home/harish/.local/lib/python3.10/site-packages (from llama-index-packs-raptor) (1.4.0)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.7.1 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-vector-stores-qdrant) (1.9.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.60.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-vector-stores-qdrant) (1.64.0)
# Requirement already satisfied: fastapi>=0.95.2 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (0.103.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (4.1.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.15.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (1.17.1)
# Requirement already satisfied: posthog>=2.4.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (3.5.0)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: pulsar-client>=3.1.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (3.4.0)
# Requirement already satisfied: build>=1.0.3 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (1.2.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (3.9.14)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (4.1.2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (29.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (8.2.3)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (0.27.0.post1)
# Requirement already satisfied: numpy>=1.22.5 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (1.26.3)
# Requirement already satisfied: importlib-resources in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (6.3.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (4.9.0)
# Requirement already satisfied: pydantic>=1.9 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (2.6.4)
# Requirement already satisfied: requests>=2.28 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pypika>=0.48.9 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: typer>=0.9.0 in /home/harish/.local/lib/python3.10/site-packages (from chromadb) (0.9.4)
# Requirement already satisfied: pyproject_hooks in /home/harish/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (1.0.0)
# Requirement already satisfied: packaging>=19.1 in /home/harish/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (23.2)
# Requirement already satisfied: tomli>=1.1.0 in /home/harish/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/harish/.local/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/harish/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: requests-oauthlib in /home/harish/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/harish/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /home/harish/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/harish/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /home/harish/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.27.0)
# Requirement already satisfied: certifi>=14.05.14 in /home/harish/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: openai>=1.1.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.23.6)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.6.0)
# Requirement already satisfied: pandas in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (2.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (2023.12.2)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (0.1.13)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (0.5.2)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.2.14)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (2.0.27)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.0.8)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (3.8.1)
# Requirement already satisfied: dataclasses-json in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (0.6.4)
# Requirement already satisfied: networkx>=3.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (3.2.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (3.9.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/lib/python3/dist-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (9.0.1)
# Requirement already satisfied: httpx in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (0.24.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (0.9.0)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (0.0.2)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (4.12.3)
# Requirement already satisfied: pymupdf<2.0.0,>=1.23.21 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (1.23.26)
# Requirement already satisfied: llama-parse<0.4.0,>=0.3.3 in /home/harish/.local/lib/python3.10/site-packages (from llama-index-readers-llama-parse<0.2.0,>=0.1.0->llama-index) (0.3.9)
# Requirement already satisfied: coloredlogs in /home/harish/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/harish/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in /home/harish/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Requirement already satisfied: sympy in /home/harish/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.22.0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-proto==1.22.0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.22.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.62.0)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (2.2.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.43b0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.43b0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.43b0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: opentelemetry-util-http==0.43b0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.43b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: setuptools>=16.0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (68.2.2)
# Requirement already satisfied: asgiref~=3.0 in /home/harish/.local/lib/python3.10/site-packages (from opentelemetry-instrumentation-asgi==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /usr/lib/python3/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/harish/.local/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (2.16.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/harish/.local/lib/python3.10/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /home/harish/.local/lib/python3.10/site-packages (from qdrant-client<2.0.0,>=1.7.1->llama-index-vector-stores-qdrant) (1.62.2)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /home/harish/.local/lib/python3.10/site-packages (from qdrant-client<2.0.0,>=1.7.1->llama-index-vector-stores-qdrant) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.28->chromadb) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/harish/.local/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb) (0.20.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/harish/.local/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: pynndescent>=0.5 in /home/harish/.local/lib/python3.10/site-packages (from umap-learn>=0.5.5->llama-index-packs-raptor) (0.5.12)
# Requirement already satisfied: numba>=0.51.2 in /home/harish/.local/lib/python3.10/site-packages (from umap-learn>=0.5.5->llama-index-packs-raptor) (0.59.1)
# Requirement already satisfied: scipy>=1.3.1 in /home/harish/.local/lib/python3.10/site-packages (from umap-learn>=0.5.5->llama-index-packs-raptor) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/harish/.local/lib/python3.10/site-packages (from scikit-learn->llama-index-packs-raptor) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/harish/.local/lib/python3.10/site-packages (from scikit-learn->llama-index-packs-raptor) (3.2.0)
# Requirement already satisfied: h11>=0.8 in /home/harish/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: python-dotenv>=0.13 in /home/harish/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/harish/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /home/harish/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/harish/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/harish/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/harish/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/harish/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/harish/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/harish/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/harish/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.4.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/harish/.local/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (23.2.0)
# Requirement already satisfied: soupsieve>1.2 in /home/harish/.local/lib/python3.10/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (2.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/harish/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/harish/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/harish/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /home/harish/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (0.17.3)
# Requirement already satisfied: sniffio in /home/harish/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.3.0)
# Requirement already satisfied: h2<5,>=3 in /home/harish/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (4.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (1.0.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (2023.12.25)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/harish/.local/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn>=0.5.5->llama-index-packs-raptor) (0.42.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/harish/.local/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (4.2.0)
# Requirement already satisfied: PyMuPDFb==1.23.22 in /home/harish/.local/lib/python3.10/site-packages (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.0->llama-index) (1.23.22)
# Requirement already satisfied: greenlet!=0.4.17 in /home/harish/.local/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/harish/.local/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/harish/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/harish/.local/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (3.20.2)
# Requirement already satisfied: pytz>=2020.1 in /home/harish/.local/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /home/harish/.local/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (2023.4)
# Requirement already satisfied: mpmath>=0.19 in /home/harish/.local/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/harish/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (1.2.0)
# Requirement already satisfied: hpack<5,>=4.0 in /home/harish/.local/lib/python3.10/site-packages (from h2<5,>=3->httpx->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (4.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /home/harish/.local/lib/python3.10/site-packages (from h2<5,>=3->httpx->llama-index-core<0.11.0,>=0.10.8.post1->llama-index) (6.0.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/harish/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.1)
# Installing collected packages: llama-index-vector-stores-chroma
# Successfully installed llama-index-vector-stores-chroma-0.1.8

# %%
from llama_index.packs.raptor import RaptorPack

# optionally download the pack to inspect/modify it yourself!
# from llama_index.core.llama_pack import download_llama_pack
# RaptorPack = download_llama_pack("RaptorPack", "./raptor_pack")
# Out:
# 2024-05-28 16:26:06.666639: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-28 16:26:06.666672: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-28 16:26:06.667527: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-28 16:26:06.675749: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-28 16:26:07.785393: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import os
# cant push this line as git prevents it 
#os.environ["OPENAI_API_KEY"] = ""

# %% [markdown]
# ## Constructing the Clusters/Hierarchy Tree

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(input_files=["./Form Master Services Agreement (Outsourcing).DOCX"]).load_data()

# %%
from llama_index.core.node_parser import SentenceSplitter
from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.vector_stores.chroma import ChromaVectorStore # type: ignore
import chromadb

client = chromadb.PersistentClient(path="./raptor_paper_db")
collection = client.get_or_create_collection("raptor")

vector_store = ChromaVectorStore(chroma_collection=collection)

raptor_pack = RaptorPack(
    documents,
    embed_model=OpenAIEmbedding(
        model="text-embedding-3-small"
    ),  # used for embedding clusters
    llm=OpenAI(model="gpt-4", temperature=0.1),  # used for generating summaries
    vector_store=vector_store,  # used for storage
    similarity_top_k=4,  # top k for each layer, or overall top-k for collapsed
    mode="collapsed",  # sets default mode
    transformations=[
        SentenceSplitter(chunk_size=400, chunk_overlap=50)
    ],  # transformations applied for ingestion
)
# Out:
# Generating embeddings for level 0.
# inside line 227
# inside line 229
# Performing clustering for level 0.
# Exception ignored on calling ctypes callback function: <function ExecutionEngine._raw_object_cache_notify at 0x71077b9d36d0>
# Traceback (most recent call last):
#   File "/home/pulkit/.local/lib/python3.10/site-packages/llvmlite/binding/executionengine.py", line 171, in _raw_object_cache_notify
#     def _raw_object_cache_notify(self, data):
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#       8 collection = client.get_or_create_collection("raptor")
#      10 vector_store = ChromaVectorStore(chroma_collection=collection)
# ---> 12 raptor_pack = RaptorPack(
#      13     documents,
#      14     embed_model=OpenAIEmbedding(
#      15         model="text-embedding-3-small"
#      16     ),  # used for embedding clusters
#      17     llm=OpenAI(model="gpt-4", temperature=0.1),  # used for generating summaries
#      18     vector_store=vector_store,  # used for storage
#      19     similarity_top_k=4,  # top k for each layer, or overall top-k for collapsed
#      20     mode="collapsed",  # sets default mode
#      21     transformations=[
#      22         SentenceSplitter(chunk_size=400, chunk_overlap=50)
#      23     ],  # transformations applied for ingestion
#      24 )
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/llama_index/packs/raptor/base.py:348, in RaptorPack.__init__(self, documents, llm, embed_model, vector_store, similarity_top_k, mode, verbose, **kwargs)
#     336 def __init__(
#     337     self,
#     338     documents: List[BaseNode],
#    (...)
#     345     **kwargs: Any,
#     346 ) -> None:
#     347     """Init params."""
# --> 348     self.retriever = RaptorRetriever(
#     349         documents,
#     350         embed_model=embed_model,
#     351         llm=llm,
#     352         similarity_top_k=similarity_top_k,
#     353         vector_store=vector_store,
#     354         mode=mode,
#     355         verbose=verbose,
#     356         **kwargs,
#     357     )
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/llama_index/packs/raptor/base.py:139, in RaptorRetriever.__init__(self, documents, tree_depth, similarity_top_k, llm, embed_model, vector_store, transformations, summary_module, existing_index, mode, **kwargs)
#     136 self.similarity_top_k = similarity_top_k
#     138 if len(documents) > 0:
# --> 139     asyncio.run(self.insert(documents))
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/asyncio/events.py:80, in Handle._run(self)
#      78 def _run(self):
#      79     try:
# ---> 80         self._context.run(self._callback, *self._args)
#      81     except (SystemExit, KeyboardInterrupt):
#      82         raise
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/asyncio/tasks.py:315, in Task.__wakeup(self, future)
#     307     self.__step(exc)
#     308 else:
#     309     # Don't pass the value of `future.result()` explicitly,
#     310     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)
#     313     # instead of `__next__()`, which is slower for futures
#     314     # that return non-generator iterators from their `__iter__`.
# --> 315     self.__step()
#     316 self = None
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/llama_index/packs/raptor/base.py:189, in RaptorRetriever.insert(self, documents)
#     186     print(f"Performing clustering for level {level}.")
#     188 # cluster the documents
# --> 189 nodes_per_cluster = get_clusters(cur_nodes, id_to_embedding)
#     191 if self._verbose:
#     192     print(
#     193         f"Generating summaries for level {level} with {len(nodes_per_cluster)} clusters."
#     194     )
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/llama_index/packs/raptor/clustering.py:132, in get_clusters(nodes, embedding_map, max_length_in_cluster, tokenizer, reduction_dimension, threshold, prev_total_length)
#     129 embeddings = np.array([np.array(embedding_map[node.id_]) for node in nodes])
#     131 # Perform the clustering
# --> 132 clusters = perform_clustering(
#     133     embeddings, dim=reduction_dimension, threshold=threshold
#     134 )
#     136 # Initialize an empty list to store the clusters of nodes
#     137 node_clusters = []
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/llama_index/packs/raptor/clustering.py:95, in perform_clustering(embeddings, dim, threshold)
#      93     n_local_clusters = 1
#      94 else:
# ---> 95     reduced_embeddings_local = local_cluster_embeddings(
#      96         global_cluster_embeddings_, dim
#      97     )
#      98     local_clusters, n_local_clusters = GMM_cluster(
#      99         reduced_embeddings_local, threshold
#     100     )
#     102 for j in range(n_local_clusters):
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/llama_index/packs/raptor/clustering.py:40, in local_cluster_embeddings(embeddings, dim, num_neighbors, metric)
#      35 def local_cluster_embeddings(
#      36     embeddings: np.ndarray, dim: int, num_neighbors: int = 10, metric: str = "cosine"
#      37 ) -> np.ndarray:
#      38     return umap.UMAP(
#      39         n_neighbors=num_neighbors, n_components=dim, metric=metric
# ---> 40     ).fit_transform(embeddings)
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/umap/umap_.py:2891, in UMAP.fit_transform(self, X, y, force_all_finite)
#    2855 def fit_transform(self, X, y=None, force_all_finite=True):
#    2856     """Fit X into an embedded space and return that transformed
#    2857     output.
#    2858
#    (...)
#    2889         Local radii of data points in the embedding (log-transformed).
#    2890     """
# -> 2891     self.fit(X, y, force_all_finite)
#    2892     if self.transform_mode == "embedding":
#    2893         if self.output_dens:
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/umap/umap_.py:2784, in UMAP.fit(self, X, y, force_all_finite)
#    2780 if self.transform_mode == "embedding":
#    2781     epochs = (
#    2782         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2783     )
# -> 2784     self.embedding_, aux_data = self._fit_embed_data(
#    2785         self._raw_data[index],
#    2786         epochs,
#    2787         init,
#    2788         random_state,  # JH why raw data?
#    2789     )
#    2791     if self.n_epochs_list is not None:
#    2792         if "embedding_list" not in aux_data:
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/umap/umap_.py:2830, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state)
#    2826 def _fit_embed_data(self, X, n_epochs, init, random_state):
#    2827     """A method wrapper for simplicial_set_embedding that can be
#    2828     replaced by subclasses.
#    2829     """
# -> 2830     return simplicial_set_embedding(
#    2831         X,
#    2832         self.graph_,
#    2833         self.n_components,
#    2834         self._initial_alpha,
#    2835         self._a,
#    2836         self._b,
#    2837         self.repulsion_strength,
#    2838         self.negative_sample_rate,
#    2839         n_epochs,
#    2840         init,
#    2841         random_state,
#    2842         self._input_distance_func,
#    2843         self._metric_kwds,
#    2844         self.densmap,
#    2845         self._densmap_kwds,
#    2846         self.output_dens,
#    2847         self._output_distance_func,
#    2848         self._output_metric_kwds,
#    2849         self.output_metric in ("euclidean", "l2"),
#    2850         self.random_state is None,
#    2851         self.verbose,
#    2852         tqdm_kwds=self.tqdm_kwds,
#    2853     )
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/umap/umap_.py:1193, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1186 embedding = (
#    1187     10.0
#    1188     * (embedding - np.min(embedding, 0))
#    1189     / (np.max(embedding, 0) - np.min(embedding, 0))
#    1190 ).astype(np.float32, order="C")
#    1192 if euclidean_output:
# -> 1193     embedding = optimize_layout_euclidean(
#    1194         embedding,
#    1195         embedding,
#    1196         head,
#    1197         tail,
#    1198         n_epochs,
#    1199         n_vertices,
#    1200         epochs_per_sample,
#    1201         a,
#    1202         b,
#    1203         rng_state,
#    1204         gamma,
#    1205         initial_alpha,
#    1206         negative_sample_rate,
#    1207         parallel=parallel,
#    1208         verbose=verbose,
#    1209         densmap=densmap,
#    1210         densmap_kwds=densmap_kwds,
#    1211         tqdm_kwds=tqdm_kwds,
#    1212         move_other=True,
#    1213     )
#    1214 else:
#    1215     embedding = optimize_layout_generic(
#    1216         embedding,
#    1217         embedding,
#    (...)
#    1233         move_other=True,
#    1234     )
#
# File ~/anaconda3/envs/llama_310/lib/python3.10/site-packages/umap/layouts.py:380, in optimize_layout_euclidean(head_embedding, tail_embedding, head, tail, n_epochs, n_vertices, epochs_per_sample, a, b, rng_state, gamma, initial_alpha, negative_sample_rate, parallel, verbose, densmap, densmap_kwds, tqdm_kwds, move_other)
#     377     dens_re_mean = 0
#     378     dens_re_cov = 0
# --> 380 optimize_fn(
#     381     head_embedding,
#     382     tail_embedding,
#     383     head,
#     384     tail,
#     385     n_vertices,
#     386     epochs_per_sample,
#     387     a,
#     388     b,
#     389     rng_state,
#     390     gamma,
#     391     dim,
#     392     move_other,
#     393     alpha,
#     394     epochs_per_negative_sample,
#     395     epoch_of_next_negative_sample,
#     396     epoch_of_next_sample,
#     397     n,
#     398     densmap_flag,
#     399     dens_phi_sum,
#     400     dens_re_sum,
#     401     dens_re_cov,
#     402     dens_re_std,
#     403     dens_re_mean,
#     404     dens_lambda,
#     405     dens_R,
#     406     dens_mu,
#     407     dens_mu_tot,
#     408 )
#     410 alpha = initial_alpha * (1.0 - (float(n) / float(n_epochs)))
#     412 if verbose and n % int(n_epochs / 10) == 0:
#
# File ~/.local/lib/python3.10/site-packages/numba/core/dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File ~/.local/lib/python3.10/site-packages/numba/core/dispatcher.py:965, in Dispatcher.compile(self, sig)
#     963 with ev.trigger_event("numba:compile", data=ev_details):
#     964     try:
# --> 965         cres = self._compiler.compile(args, return_type)
#     966     except errors.ForceLiteralArg as e:
#     967         def folded(args, kws):
#
# File ~/.local/lib/python3.10/site-packages/numba/core/dispatcher.py:125, in _FunctionCompiler.compile(self, args, return_type)
#     124 def compile(self, args, return_type):
# --> 125     status, retval = self._compile_cached(args, return_type)
#     126     if status:
#     127         return retval
#
# File ~/.local/lib/python3.10/site-packages/numba/core/dispatcher.py:139, in _FunctionCompiler._compile_cached(self, args, return_type)
#     136     pass
#     138 try:
# --> 139     retval = self._compile_core(args, return_type)
#     140 except errors.TypingError as e:
#     141     self._failed_cache[key] = e
#
# File ~/.local/lib/python3.10/site-packages/numba/core/dispatcher.py:152, in _FunctionCompiler._compile_core(self, args, return_type)
#     149 flags = self._customize_flags(flags)
#     151 impl = self._get_implementation(args, {})
# --> 152 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     153                               self.targetdescr.target_context,
#     154                               impl,
#     155                               args=args, return_type=return_type,
#     156                               flags=flags, locals=self.locals,
#     157                               pipeline_class=self.pipeline_class)
#     158 # Check typing error if object mode is used
#     159 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler.py:770, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     746 """Compiler entry point
#     747
#     748 Parameter
#    (...)
#     766     compiler pipeline
#     767 """
#     768 pipeline = pipeline_class(typingctx, targetctx, library,
#     769                           args, return_type, flags, locals)
# --> 770 return pipeline.compile_extra(func)
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler.py:461, in CompilerBase.compile_extra(self, func)
#     459 self.state.lifted = ()
#     460 self.state.lifted_from = None
# --> 461 return self._compile_bytecode()
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler.py:529, in CompilerBase._compile_bytecode(self)
#     525 """
#     526 Populate and run pipeline for bytecode input
#     527 """
#     528 assert self.state.func_ir is None
# --> 529 return self._compile_core()
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler.py:495, in CompilerBase._compile_core(self)
#     493 res = None
#     494 try:
# --> 495     pm.run(self.state)
#     496     if self.state.cr is not None:
#     497         break
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/.local/lib/python3.10/site-packages/numba/core/compiler_machinery.py:273, in PassManager._runPass.<locals>.check(func, compiler_state)
#     272 def check(func, compiler_state):
# --> 273     mangled = func(compiler_state)
#     274     if mangled not in (True, False):
#     275         msg = ("CompilerPass implementations should return True/False. "
#     276                "CompilerPass with name '%s' did not.")
#
# File ~/.local/lib/python3.10/site-packages/numba/core/typed_passes.py:495, in BaseNativeLowering.run_pass(self, state)
#     489     state['cr'] = _LowerResult(fndesc, call_helper,
#     490                                cfunc=None, env=env)
#     491 else:
#     492     # Prepare for execution
#     493     # Insert native function for use by other jitted-functions.
#     494     # We also register its library to allow for inlining.
# --> 495     cfunc = targetctx.get_executable(library, fndesc, env)
#     496     targetctx.insert_user_function(cfunc, fndesc, [library])
#     497     state['cr'] = _LowerResult(fndesc, call_helper,
#     498                                cfunc=cfunc, env=env)
#
# File ~/.local/lib/python3.10/site-packages/numba/core/cpu.py:239, in CPUContext.get_executable(self, library, fndesc, env)
#     226 """
#     227 Returns
#     228 -------
#    (...)
#     236     an execution environment (from _dynfunc)
#     237 """
#     238 # Code generation
# --> 239 fnptr = library.get_pointer_to_function(
#     240     fndesc.llvm_cpython_wrapper_name)
#     242 # Note: we avoid reusing the original docstring to avoid encoding
#     243 # issues on Python 2, see issue #1908
#     244 doc = "compiled wrapper for %r" % (fndesc.qualname,)
#
# File ~/.local/lib/python3.10/site-packages/numba/core/codegen.py:989, in JITCodeLibrary.get_pointer_to_function(self, name)
#     975 def get_pointer_to_function(self, name):
#     976     """
#     977     Generate native code for function named *name* and return a pointer
#     978     to the start of the function (as an integer).
#    (...)
#     987         - non-zero if the symbol is defined.
#     988     """
# --> 989     self._ensure_finalized()
#     990     ee = self._codegen._engine
#     991     if not ee.is_symbol_defined(name):
#
# File ~/.local/lib/python3.10/site-packages/numba/core/codegen.py:567, in CodeLibrary._ensure_finalized(self)
#     565 def _ensure_finalized(self):
#     566     if not self._finalized:
# --> 567         self.finalize()
#
# File ~/.local/lib/python3.10/site-packages/numba/core/codegen.py:762, in CPUCodeLibrary.finalize(self)
#     756         self._final_module.link_in(
#     757             library._get_module_for_linking(), preserve=True,
#     758         )
#     760 # Optimize the module after all dependences are linked in above,
#     761 # to allow for inlining.
# --> 762 self._optimize_final_module()
#     764 self._final_module.verify()
#     765 self._finalize_final_module()
#
# File ~/.local/lib/python3.10/site-packages/numba/core/codegen.py:682, in CPUCodeLibrary._optimize_final_module(self)
#     679 full_name = "Module passes (full optimization)"
#     680 with self._recorded_timings.record(full_name):
#     681     # The full optimisation suite is then run on the refop pruned IR
# --> 682     self._codegen._mpm_full.run(self._final_module)
#
# File ~/.local/lib/python3.10/site-packages/llvmlite/binding/passmanagers.py:685, in ModulePassManager.run(self, module, remarks_file, remarks_format, remarks_filter)
#     670 """
#     671 Run optimization passes on the given module.
#     672
#    (...)
#     682     The filter that should be applied to the remarks output.
#     683 """
#     684 if remarks_file is None:
# --> 685     return ffi.lib.LLVMPY_RunPassManager(self, module)
#     686 else:
#     687     r = ffi.lib.LLVMPY_RunPassManagerWithRemarks(
#     688         self, module, _encode_string(remarks_format),
#     689         _encode_string(remarks_filter),
#     690         _encode_string(remarks_file))
#
# File ~/.local/lib/python3.10/site-packages/llvmlite/binding/ffi.py:190, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     188 def __call__(self, *args, **kwargs):
#     189     with self._lock:
# --> 190         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Retrieval

# %%
nodes = raptor_pack.run("What are the intellectual property rights of the vendor?", mode="collapsed")
print(len(nodes))
print(nodes[0].text)
# Out:
# 2
# The agreement outlines the terms related to changes in charges, intellectual property rights, ownership of work products, disclosure of inventions, and software provisions between the Provider and the Client. It specifies that any changes in charges must be agreed upon and adjusted accordingly. The agreement also addresses the ownership of software, work products, and modifications, with the Client retaining all rights and interests. It further discusses the use of Provider Proprietary Materials and the disclosure of inventions made during the agreement. Additionally, it covers the installation of upgrades and modifications to software, as well as the granting of rights and licenses related to Provider Patents within specific industries.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 nodes = raptor_pack.run("What are the intellectual property rights of the vendor?", mode="collapsed")
#       2 print(len(nodes))
#       3 print(nodes[0].text)
#
# NameError: name 'raptor_pack' is not defined

# %%
nodes = raptor_pack.run(
    "What are the intellectual property rights of the vendor?", mode="tree_traversal"
)
print(len(nodes))
print(nodes[0].text)
# Out:
# Retrieved parent IDs from level 2: ['0f0c386b-12f5-460c-9fb2-5d65b0024c7c']
# Retrieved 2 from parents at level 2.
# Retrieved parent IDs from level 1: ['750e2166-637d-4a6a-8b6c-86b69ba6ad97', 'd6ead990-a89c-420d-b1bb-8108516f4b8f']
# Retrieved 4 from parents at level 1.
# Retrieved parent IDs from level 0: ['a9cc1f53-70ae-4e05-bfb5-e409ccd914f6', '637bef95-1443-4125-8ae0-4a7793896c0a']
# Retrieved 4 from parents at level 0.
# 4
# The territorial extent of the rights in the Work Product assigned to [XXXXXXXX] by Provider and/or the Provider Personnel under this Agreement shall extend to all the countries in the world.  The assignment of the Intellectual Property Rights in the Work Product by Provider and/or the Provider Personnel to [XXXXXXXX] shall be royalty-free absolute, irrevocable and perpetual.
#
# With respect to any Services performed in India, the Parties agree that, without limitation of any other [XXXXXXXX] rights or remedies under the Agreement, the following provisions shall apply: (i) Provider acknowledges that notwithstanding the provisions of Section 19(4) of the Indian Copyright Act, 1957, any assignment to [XXXXXXXX] of all Intellectual Property Rights to Work Product in connection with this Agreement, any SOW and/or Work Order shall not lapse nor the right transferred therein revert to Provider and/or the Provider Personnel even if [XXXXXXXX] and the successors and permitted assigns of [XXXXXXXX] do not exercise the rights under assignment within a period of one (1) year from the date of such assignment.  Provider shall not, and shall ensure that its Affiliates and the Provider Personnel do not, take any steps against [XXXXXXXX] and the successors and permitted assigns of [XXXXXXXX] under Section 19A of the Copyright Act, 1957.  For the avoidance of doubt, the Parties agree that in the event of the commencement of any winding up proceeding by or against Provider under the Indian Companies Act, 1956, [XXXXXXXX] shall be entitled to retain all of its rights under this Agreement, any SOW and/or Work Order.
#
# Provider Software.

# %% [markdown]
# ## Multiquery
#
# Since we saved to a vector store, we can also use it again! (For local vector stores, there is a `persist` and `from_persist_dir` method on the retriever)

# %%
from llama_index.packs.raptor import RaptorRetriever
from llama_index.core import QueryBundle
from llama_index.llms.openai import OpenAI
from llama_index.core import PromptTemplate
from llama_index.core.llms.utils import LLMType
from llama_index.core.schema import NodeWithScore
from llama_index.core.indices.base import BaseIndex
from llama_index.core.retrievers import BaseRetriever
from llama_index.core.embeddings.utils import EmbedType
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.legacy.vector_stores import ChromaVectorStore
from llama_index.core.base.llms.types import CompletionResponse
from llama_index.core.node_parser import SentenceWindowNodeParser

from llama_index.core.retrievers import BaseRetriever
from llama_index.core import get_response_synthesizer
from llama_index.legacy.core.response.schema import RESPONSE_TYPE
from llama_index.core.response_synthesizers import BaseSynthesizer
from llama_index.core.query_engine import CustomQueryEngine, BaseQueryEngine
from typing import Any, List
from tqdm.asyncio import tqdm

class MultiQueriesRetriever(BaseRetriever):
    def __init__(self, base_retriever: BaseRetriever, model:OpenAI):
        self.template = PromptTemplate("""You are an AI language model assistant. Your task is to generate Five
    different versions of the given user question to retrieve relevant documents from a vector
    database. By generating multiple perspectives on the user question, your goal is to help
    the user overcome some of the limitations of the distance-based similarity search.
    Provide these alternative questions seperated by newlines.
    Original question: {question}""")
        self._retrievers = [base_retriever]
        self.base_retriever = base_retriever
        self.model = model
    
    def gen_queries(self, query) -> List[str]:
        gen_queries_model = OpenAI(model="gpt-3-turbo", temperature=1.5)
        prompt = self.template.format(question=query)
        res = self.model.complete(prompt)
        return res.text.split("\n")

    async def run_gen_queries(self,generated_queries: List[str]) -> List[NodeWithScore]:
        tasks = list(map(lambda q: self.base_retriever.aretrieve(q), generated_queries)) 
        res = await tqdm.gather(*tasks)
        return res[0]

    def _retrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
        return list()

    async def _aretrieve(self, query_bundle: QueryBundle) -> List[NodeWithScore]:
        query = query_bundle.query_str
        generated_queries = self.gen_queries(query)
        query_res = await self.run_gen_queries(generated_queries)
        return query_res

retriever = RaptorRetriever(
    [],
    embed_model=OpenAIEmbedding(
        model="text-embedding-3-small"
    ),  # used for embedding clusters
    llm=OpenAI(model="gpt-4", temperature=0.1),  # used for generating summaries
    vector_store=vector_store,  # used for storage
    similarity_top_k=8,  # top k for each layer, or overall top-k for collapsed
    mode="collapsed",  # sets default mode
)
mr = MultiQueriesRetriever(retriever, OpenAI(model="gpt-4", temperature=0.1))

# %%
# if using a default vector store
# retriever.persist("./persist")
# retriever = RaptorRetriever.from_persist_dir("./persist", ...)

# %% [markdown]
# ## Query Engine

# %%
from rich.pretty import pprint

def pretty_print(title: str=None, content: Any=None):
    if title is None:
        print(content)
        return
    print(title)
    pprint(content)

ls = mr.gen_queries("Explain the responsibilities of the vendor for compliance .")


pretty_print("ls", ls)
rls = await mr.run_gen_queries(ls)
pretty_print("rls", rls)
# Out:
# ls
# [
# │   'What are the duties of a vendor in ensuring compliance?',
# │   'Can you describe the obligations of a vendor in relation to compliance?',
# │   'What are the compliance-related tasks a vendor is responsible for?',
# │   'In what ways is a vendor responsible for maintaining compliance?',
# │   'What compliance duties are expected from a vendor?'
# ]
#   0%|          | 0/5 [00:00<?, ?it/s]
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# 100%|██████████| 5/5 [00:00<00:00,  7.73it/s]
# rls
# [
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='0918adcc-a074-474d-b584-fb947be95965',
# │   │   │   embedding=None,
# │   │   │   metadata={'level': 0, 'parent_id': '6de3996c-79e3-49c5-b776-d8ac67d55d9d'},
# │   │   │   excluded_embed_metadata_keys=['level', 'parent_id'],
# │   │   │   excluded_llm_metadata_keys=['level', 'parent_id'],
# │   │   │   relationships={},
# │   │   │   text='The provider is obligated to deliver services and products that do not infringe on any Intellectual Property Rights. They must have all necessary permits to perform the services and are required to maintain these permits throughout the term of the agreement. The provider must ensure that none of their personnel have been convicted of a felony or a misdemeanor involving violence, sexual misconduct, or dishonesty. They are also required to perform criminal background checks on all personnel. \n\nThe provider must maintain necessary certifications and documentation, including Employment Eligibility Verification form I9s, and insurance for its employees. They are solely responsible for employment taxes, benefits, and Workers’ Compensation Insurance. \n\nThe provider\'s information systems must be Date Compliant and Currency Compliant. If non-compliance is detected, the provider must immediately notify the client and promptly correct the issue. \n\nThe provider must comply with all applicable laws, including federal "anti-kickback" acts and the U.S. Foreign Corrupt Practices Act. If noncompliance is charged, the provider must immediately notify the client and remedy the noncompliance at their own cost. They are responsible for any fines or penalties incurred due to noncompliance. \n\nThe provider must not accept any fee, compensation, remuneration, or reimbursement that would constitute a breach of the agreement. They must also ensure they do not violate any of the client\'s policies regarding inducements, gifts, or gratuities. The provider must disclose any relations with third parties that could jeopardize their ability to provide services. They are not allowed to accept any rebate, commission, or other consideration related to the services from any third party without passing along the full benefit to the client.',
# │   │   │   start_char_idx=None,
# │   │   │   end_char_idx=None,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.41456054597893705
# │   ),
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='c1aaf34e-c534-4e78-bc56-da528dd7a6b5',
# │   │   │   embedding=None,
# │   │   │   metadata={'level': 0, 'parent_id': 'd1aea239-2928-4ea0-800e-a5998d4e8218'},
# │   │   │   excluded_embed_metadata_keys=['level', 'parent_id'],
# │   │   │   excluded_llm_metadata_keys=['level', 'parent_id'],
# │   │   │   relationships={},
# │   │   │   text='The text outlines the terms of a Master Services Agreement for outsourcing services. The provider is required to comply with all laws related to the delivery of services, the client\'s receipt or use of services, and the client\'s operations. The provider must also adhere to any compliance directives given by the client. The provider is expected to assist the client in complying with all laws, including export and import laws, HIPAA regulations, and privacy laws.\n\nThe provider must also follow the client\'s policies and procedures, which include notifying the client when a provider personnel terminates their relationship with the provider, complying with regulations regarding security, parking, equipment usage, and safety, adhering to the client\'s Information Security Policy and Code of Ethics, and complying with the client\'s minority participation plans.\n\nThe provider is required to maintain confidentiality and ensure that all provider personnel are bound by a confidentiality agreement. The provider must also respect the client\'s data ownership and ensure that their services do not infringe on any intellectual property rights. The provider is expected to have all necessary permits to perform the services and must conduct criminal background checks on all personnel.\n\nThe provider is responsible for maintaining necessary certifications and documentation for its employees, including employment eligibility verification forms and insurance. The provider\'s information systems must be date and currency compliant. The provider personnel should not have any criminal convictions or be named on the U.S. Office of Foreign Assets Control’s Specially Designated Nationals list.\n\nThe provider must comply with all applicable laws, including federal "anti-kickback" acts and the U.S. Foreign Corrupt Practices Act. The provider is responsible for any fines or penalties incurred due to noncompliance with laws. The provider is also expected to maintain all necessary controls, operations, and systems to enable the client to comply with its obligations.',
# │   │   │   start_char_idx=None,
# │   │   │   end_char_idx=None,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.40089199975067197
# │   ),
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='baf2ddd8-23fa-4cef-9271-406543a7a16d',
# │   │   │   embedding=None,
# │   │   │   metadata={
# │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   'file_size': 195063,
# │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   'last_modified_date': '2024-05-22',
# │   │   │   │   'parent_id': 'c1aaf34e-c534-4e78-bc56-da528dd7a6b5'
# │   │   │   },
# │   │   │   excluded_embed_metadata_keys=[
# │   │   │   │   'file_name',
# │   │   │   │   'file_type',
# │   │   │   │   'file_size',
# │   │   │   │   'creation_date',
# │   │   │   │   'last_modified_date',
# │   │   │   │   'last_accessed_date',
# │   │   │   │   'parent_id'
# │   │   │   ],
# │   │   │   excluded_llm_metadata_keys=[
# │   │   │   │   'file_name',
# │   │   │   │   'file_type',
# │   │   │   │   'file_size',
# │   │   │   │   'creation_date',
# │   │   │   │   'last_modified_date',
# │   │   │   │   'last_accessed_date',
# │   │   │   │   'parent_id'
# │   │   │   ],
# │   │   │   relationships={
# │   │   │   │   <NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='bc010c56-cdec-41dc-bfba-4d4cf722123c',
# │   │   │   │   │   node_type=<ObjectType.DOCUMENT: '4'>,
# │   │   │   │   │   metadata={
# │   │   │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   │   │   'file_size': 195063,
# │   │   │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   │   │   'last_modified_date': '2024-05-22'
# │   │   │   │   │   },
# │   │   │   │   │   hash='27ded1807e5fa4c548072b2b28c5d14c4b69a4dae0c44304f6b65fb58655aba7'
# │   │   │   │   ),
# │   │   │   │   <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='acee8cac-ca25-4341-a1df-1646ad650832',
# │   │   │   │   │   node_type=<ObjectType.TEXT: '1'>,
# │   │   │   │   │   metadata={
# │   │   │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   │   │   'file_size': 195063,
# │   │   │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   │   │   'last_modified_date': '2024-05-22'
# │   │   │   │   │   },
# │   │   │   │   │   hash='a11d8f296c2882430e44e08e916148f0416ac0c3c134e22563197854e945a7d3'
# │   │   │   │   ),
# │   │   │   │   <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='5d74b35c-142c-4d99-b682-39b02d7a3457',
# │   │   │   │   │   node_type=<ObjectType.TEXT: '1'>,
# │   │   │   │   │   metadata={},
# │   │   │   │   │   hash='da16970cff70046634e101a2ea5c8ba4a42cda25c1c027fea38f0b661861bc72'
# │   │   │   │   )
# │   │   │   },
# │   │   │   text='Office of Foreign Assets Control’s Specially Designated Nationals list.\xa0 \n\nNo Provider Personnel who has physical contact with [XXXXXXXX]’s or [XXXXXXXX] Affiliates’ respective employees, customers, clients, or vendors has been convicted of any misdemeanor involving violence or sexual misconduct. \n\nProvider shall comply with, and shall ensure that all Services, Software and Deliverables comply with, all applicable Laws in accordance with Provider’s obligations under ARTICLE 5, including, but not limited to, federal “anti-kickback” acts, and the U.S. Foreign Corrupt Practices Act.  Without limitation of the foregoing, Provider represents and warrants that (i) the Services, Software and Deliverables comply with all Laws applicable to their use and operation and that [XXXXXXXX]’s use and operation of such Services, Software and Deliverables will not violate any Laws or the Policies and Procedures, and (ii) that Provider shall take all necessary actions to ensure that Provider and [XXXXXXXX] are, at all times, in compliance with such Laws.  If a charge of noncompliance with any Law occurs, Provider will immediately notify [XXXXXXXX] of such charge in writing and, at its own cost, promptly remedy such noncompliance.  Provider will be responsible for any fines or penalties incurred by [XXXXXXXX] arising from Provider’s noncompliance with Laws or [XXXXXXXX]’s noncompliance with Laws due to use by [XXXXXXXX] of any Services, Software or Deliverables.  At all times during the SOA Compliance Period, Provider shall, and shall cause each of its Affiliates and subcontractors to: \n\n\t(i) maintain in effect all controls, operations and systems necessary and appropriate to enable [XXXXXXXX] and [XXXXXXXX] Affiliates to comply with its obligations under SOA with respect to the Services;',
# │   │   │   start_char_idx=146823,
# │   │   │   end_char_idx=148622,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.38303937222695994
# │   ),
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='e1b2324b-8b09-4952-aa7f-8cf3df3e9394',
# │   │   │   embedding=None,
# │   │   │   metadata={
# │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   'file_size': 195063,
# │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   'last_modified_date': '2024-05-22',
# │   │   │   │   'parent_id': '0918adcc-a074-474d-b584-fb947be95965'
# │   │   │   },
# │   │   │   excluded_embed_metadata_keys=[
# │   │   │   │   'file_name',
# │   │   │   │   'file_type',
# │   │   │   │   'file_size',
# │   │   │   │   'creation_date',
# │   │   │   │   'last_modified_date',
# │   │   │   │   'last_accessed_date',
# │   │   │   │   'parent_id'
# │   │   │   ],
# │   │   │   excluded_llm_metadata_keys=[
# │   │   │   │   'file_name',
# │   │   │   │   'file_type',
# │   │   │   │   'file_size',
# │   │   │   │   'creation_date',
# │   │   │   │   'last_modified_date',
# │   │   │   │   'last_accessed_date',
# │   │   │   │   'parent_id'
# │   │   │   ],
# │   │   │   relationships={
# │   │   │   │   <NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='af3c481f-f8cb-490d-a881-03a1554d0cd3',
# │   │   │   │   │   node_type=<ObjectType.DOCUMENT: '4'>,
# │   │   │   │   │   metadata={
# │   │   │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   │   │   'file_size': 195063,
# │   │   │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   │   │   'last_modified_date': '2024-05-22'
# │   │   │   │   │   },
# │   │   │   │   │   hash='27ded1807e5fa4c548072b2b28c5d14c4b69a4dae0c44304f6b65fb58655aba7'
# │   │   │   │   ),
# │   │   │   │   <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='0e4c006c-b359-48cb-9100-e88678bb16de',
# │   │   │   │   │   node_type=<ObjectType.TEXT: '1'>,
# │   │   │   │   │   metadata={
# │   │   │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   │   │   'file_size': 195063,
# │   │   │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   │   │   'last_modified_date': '2024-05-22'
# │   │   │   │   │   },
# │   │   │   │   │   hash='a11d8f296c2882430e44e08e916148f0416ac0c3c134e22563197854e945a7d3'
# │   │   │   │   ),
# │   │   │   │   <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='4d043922-2cf7-42ff-94c0-5b438d9dbc92',
# │   │   │   │   │   node_type=<ObjectType.TEXT: '1'>,
# │   │   │   │   │   metadata={},
# │   │   │   │   │   hash='da16970cff70046634e101a2ea5c8ba4a42cda25c1c027fea38f0b661861bc72'
# │   │   │   │   )
# │   │   │   },
# │   │   │   text='Office of Foreign Assets Control’s Specially Designated Nationals list.\xa0 \n\nNo Provider Personnel who has physical contact with [XXXXXXXX]’s or [XXXXXXXX] Affiliates’ respective employees, customers, clients, or vendors has been convicted of any misdemeanor involving violence or sexual misconduct. \n\nProvider shall comply with, and shall ensure that all Services, Software and Deliverables comply with, all applicable Laws in accordance with Provider’s obligations under ARTICLE 5, including, but not limited to, federal “anti-kickback” acts, and the U.S. Foreign Corrupt Practices Act.  Without limitation of the foregoing, Provider represents and warrants that (i) the Services, Software and Deliverables comply with all Laws applicable to their use and operation and that [XXXXXXXX]’s use and operation of such Services, Software and Deliverables will not violate any Laws or the Policies and Procedures, and (ii) that Provider shall take all necessary actions to ensure that Provider and [XXXXXXXX] are, at all times, in compliance with such Laws.  If a charge of noncompliance with any Law occurs, Provider will immediately notify [XXXXXXXX] of such charge in writing and, at its own cost, promptly remedy such noncompliance.  Provider will be responsible for any fines or penalties incurred by [XXXXXXXX] arising from Provider’s noncompliance with Laws or [XXXXXXXX]’s noncompliance with Laws due to use by [XXXXXXXX] of any Services, Software or Deliverables.  At all times during the SOA Compliance Period, Provider shall, and shall cause each of its Affiliates and subcontractors to: \n\n\t(i) maintain in effect all controls, operations and systems necessary and appropriate to enable [XXXXXXXX] and [XXXXXXXX] Affiliates to comply with its obligations under SOA with respect to the Services;',
# │   │   │   start_char_idx=146823,
# │   │   │   end_char_idx=148622,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.38295785354565426
# │   ),
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='d1aea239-2928-4ea0-800e-a5998d4e8218',
# │   │   │   embedding=None,
# │   │   │   metadata={'level': 1, 'parent_id': '20aea449-5b61-41eb-9e51-a4bbc7614fad'},
# │   │   │   excluded_embed_metadata_keys=['level', 'parent_id'],
# │   │   │   excluded_llm_metadata_keys=['level', 'parent_id'],
# │   │   │   relationships={},
# │   │   │   text="The Master Services Agreement (Outsourcing) outlines the responsibilities of the service provider and the client. The provider is responsible for all taxes, except sales tax, related to the services provided, and for remitting all collected or withheld taxes. The provider is also responsible for pass-through expenses unless otherwise agreed. In terms of invoicing and payment, the provider must deliver a consolidated invoice monthly, and the client is obliged to pay correct invoices within 45 days of receipt.\n\nThe agreement includes a 30-day User Acceptance Testing Period for review and compliance testing of deliverables or services. If a deliverable or service fails to meet the specifications, the provider must correct it within 30 days. If the provider is unable to correct and redeliver the deliverable or re-perform the service within the correction period, they must provide a written notice with an estimate of the required time for correction.\n\nThe provider is required to comply with all laws related to the delivery of services, the client's receipt or use of services, and the client's operations. The provider must also adhere to any compliance directives given by the client. The provider is expected to assist the client in complying with all laws, including export and import laws, HIPAA regulations, and privacy laws.\n\nThe provider's security policies should include continual risk assessment and re-assessment of the security of data and systems, identification of internal and external threats that could lead to a security breach, and the implementation of appropriate protection against such risks. In the event of a security breach, the provider must notify the client, perform a root cause analysis, investigate the breach, provide a remediation plan, remediate the effects of the breach, and cooperate with the client and any law enforcement or regulatory official investigating the breach.\n\nThe provider is required to maintain complete and accurate records of all financial and non-financial transactions under all work orders for a period of ten years. The provider must allow the other party access to these records for audit purposes during normal business hours and for a period of ten years. The provider must also perform a security audit of its systems and facilities to ensure the security of data, including yearly penetration tests.\n\nFinally, the provider is required to comply with all applicable laws, including employment laws and U.S. immigration laws. They must provide proof of compliance within 30 days of request. The provider is also obligated to notify the client of any changes in laws that affect the delivery of services and to provide solutions for implementing these changes.",
# │   │   │   start_char_idx=None,
# │   │   │   end_char_idx=None,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.3712952083333836
# │   ),
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='69b4c1c6-ac07-48fa-96b8-636da7193941',
# │   │   │   embedding=None,
# │   │   │   metadata={'level': 0, 'parent_id': 'd1aea239-2928-4ea0-800e-a5998d4e8218'},
# │   │   │   excluded_embed_metadata_keys=['level', 'parent_id'],
# │   │   │   excluded_llm_metadata_keys=['level', 'parent_id'],
# │   │   │   relationships={},
# │   │   │   text="The text outlines the terms of a Master Services Agreement for outsourcing. The provider is required to comply with all applicable laws, including employment laws and U.S. immigration laws. They must provide proof of compliance within 30 days of request. The provider is also obligated to notify the client of any changes in laws that affect the delivery of services and to provide solutions for implementing these changes. \n\nIf a change in law prevents or delays the provider from fulfilling its obligations, a workaround will be developed and implemented. The provider must also adhere to the client's policies and procedures, including security procedures, immigration/visa policies, procurement policies, code of conduct, and privacy policies. \n\nThe provider is responsible for correcting any issues caused by a Trap Door or a Virus at no additional cost. They must also ensure that their employees and subcontractors comply with U.S. immigration laws and related laws. \n\nThe provider is required to submit unaudited consolidated interim financial statements 45 days after the end of each fiscal quarter and audited consolidated interim financial statements 90 days after the end of each fiscal year. \n\nFinally, the provider must promptly notify the client in writing if the senior unsecured debt rating for the provider or the provider's parent company falls below certain levels or is withdrawn by Moody’s Investor Services, Inc. or Standard & Poor’s Rating Services.",
# │   │   │   start_char_idx=None,
# │   │   │   end_char_idx=None,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.37034715924272754
# │   ),
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='94c65de7-509b-48e6-baad-0f60ba27322f',
# │   │   │   embedding=None,
# │   │   │   metadata={'level': 0, 'parent_id': '6de3996c-79e3-49c5-b776-d8ac67d55d9d'},
# │   │   │   excluded_embed_metadata_keys=['level', 'parent_id'],
# │   │   │   excluded_llm_metadata_keys=['level', 'parent_id'],
# │   │   │   relationships={},
# │   │   │   text="The text outlines the terms of a Master Services Agreement for outsourcing. The provider is not allowed to make changes to the client's equipment, software, or related resources without prior written approval. If the provider or its subcontractor causes any errors or inaccuracies, they are responsible for correcting them at no charge and covering any losses or penalties incurred. The provider is also not allowed to delegate or subcontract any of its obligations without the client's prior written consent.\n\nThe provider must comply with all laws related to the delivery of the services and the client's use of the services. This includes compliance with export and import laws, HIPAA regulations, and other laws regarding the privacy of information. The provider must also provide proof of compliance with all employer-related laws, such as tax withholding and insurance payments.\n\nThe provider must notify the client of any changes in laws that affect the delivery of services and work with the client to determine how to adapt. If a change in law prevents or delays the provider from fulfilling its obligations, a workaround will be developed. The provider must also comply with the client's policies and procedures.\n\nThe provider is responsible for correcting any issues caused by a Trap Door or a Virus at no additional cost. They must also comply with U.S. immigration laws for their employees and ensure that any subcontractors do the same.\n\nFinally, the provider is required to deliver unaudited consolidated interim financial statements for each fiscal quarter, accompanied by a certificate from the chief financial officer confirming their accuracy.",
# │   │   │   start_char_idx=None,
# │   │   │   end_char_idx=None,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.3684797706673253
# │   ),
# │   NodeWithScore(
# │   │   node=TextNode(
# │   │   │   id_='8ad61f9e-be0e-44d3-9f67-a6bdbeb5f577',
# │   │   │   embedding=None,
# │   │   │   metadata={
# │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   'file_size': 195063,
# │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   'last_modified_date': '2024-05-22',
# │   │   │   │   'parent_id': 'c1aaf34e-c534-4e78-bc56-da528dd7a6b5'
# │   │   │   },
# │   │   │   excluded_embed_metadata_keys=[
# │   │   │   │   'file_name',
# │   │   │   │   'file_type',
# │   │   │   │   'file_size',
# │   │   │   │   'creation_date',
# │   │   │   │   'last_modified_date',
# │   │   │   │   'last_accessed_date',
# │   │   │   │   'parent_id'
# │   │   │   ],
# │   │   │   excluded_llm_metadata_keys=[
# │   │   │   │   'file_name',
# │   │   │   │   'file_type',
# │   │   │   │   'file_size',
# │   │   │   │   'creation_date',
# │   │   │   │   'last_modified_date',
# │   │   │   │   'last_accessed_date',
# │   │   │   │   'parent_id'
# │   │   │   ],
# │   │   │   relationships={
# │   │   │   │   <NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='bc010c56-cdec-41dc-bfba-4d4cf722123c',
# │   │   │   │   │   node_type=<ObjectType.DOCUMENT: '4'>,
# │   │   │   │   │   metadata={
# │   │   │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   │   │   'file_size': 195063,
# │   │   │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   │   │   'last_modified_date': '2024-05-22'
# │   │   │   │   │   },
# │   │   │   │   │   hash='27ded1807e5fa4c548072b2b28c5d14c4b69a4dae0c44304f6b65fb58655aba7'
# │   │   │   │   ),
# │   │   │   │   <NodeRelationship.PREVIOUS: '2'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='688a067f-bb4b-487a-aa63-7bd85261bed0',
# │   │   │   │   │   node_type=<ObjectType.TEXT: '1'>,
# │   │   │   │   │   metadata={
# │   │   │   │   │   │   'file_name': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_path': 'Form Master Services Agreement (Outsourcing).DOCX',
# │   │   │   │   │   │   'file_type': 'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
# │   │   │   │   │   │   'file_size': 195063,
# │   │   │   │   │   │   'creation_date': '2024-05-22',
# │   │   │   │   │   │   'last_modified_date': '2024-05-22'
# │   │   │   │   │   },
# │   │   │   │   │   hash='12901748e05255f09ce9eafa2c1cd036d48978db7d682a97d9fad635f3bff884'
# │   │   │   │   ),
# │   │   │   │   <NodeRelationship.NEXT: '3'>: RelatedNodeInfo(
# │   │   │   │   │   node_id='acee8cac-ca25-4341-a1df-1646ad650832',
# │   │   │   │   │   node_type=<ObjectType.TEXT: '1'>,
# │   │   │   │   │   metadata={},
# │   │   │   │   │   hash='87e792f249ec50017fa6a2c7077edd53ffad279f1a3c3a6503b46c5755bdb0ae'
# │   │   │   │   )
# │   │   │   },
# │   │   │   text='Provider shall provide its Services (including any Deliverables) under this Agreement and all Work Orders in a manner that does not infringe, or constitute an infringement or misappropriation of, any Intellectual Property Right.  Provider represents and warrants that the Services (including any Deliverables), Work Product and Software and use thereof by [XXXXXXXX] do not, and will not, infringe any Intellectual Property Right owned or controlled by any other person. \n\nProvider has obtained all requisite Permits necessary to perform the Services and to provide all related materials and services required under this Agreement and will take all lawful steps necessary to maintain the Permits during the Term.\n\nIn accordance with [XXXXXXXX]’s Policies and Procedures and the Federal Violent Crime Control and Law Enforcement Act of 1994 (“VCCLEA”), no Provider Personnel has ever been convicted of (i) a felony or (ii)\xa0a misdemeanor involving violence, sexual misconduct or dishonesty.  Provider warrants that it has performed and that each of Provider’s subcontractors has performed a criminal background check on each Provider Personnel prior to their assignment to perform any Services under this Agreement.  Such criminal background checks shall be performed in accordance with the standards set forth in Exhibit\xa08.  Provider further warrants that Provider will  perform and ensure that each of Provider’s subcontractors will perform such criminal background checks on all new or replacement Provider Personnel (as applicable) prior to their assignment to perform any Services under this Agreement.  [XXXXXXXX] shall be entitled to audit compliance with this Section\xa014.2(f) pursuant to Section\xa011.1(b).',
# │   │   │   start_char_idx=143350,
# │   │   │   end_char_idx=145060,
# │   │   │   text_template='{metadata_str}\n\n{content}',
# │   │   │   metadata_template='{key}: {value}',
# │   │   │   metadata_seperator='\n'
# │   │   ),
# │   │   score=0.35429696647259695
# │   )
# ]

# %%
from llama_index.core.query_engine import RetrieverQueryEngine

# query_engine = RetrieverQueryEngine.from_args(
#     mr, llm=OpenAI(model="gpt-4", temperature=0.1)
# )

# %%
query_text = """4. Explain the responsibilities of the vendor for compliance ."""
final_res = await RetrieverQueryEngine(mr).aquery(query_text)
# Out:
# inside line 227
# inside line 229
# inside line 227
# inside line 229
#   0%|          | 0/5 [00:00<?, ?it/s]
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# 100%|██████████| 5/5 [00:00<00:00,  7.84it/s]
# inside line 227
# inside line 229
# inside line 227
# inside line 229
# inside line 227
# inside line 229

# %%
final_res.response
# Out:
# 'The vendor is responsible for ensuring compliance with all applicable laws, including federal "anti-kickback" acts and the U.S. Foreign Corrupt Practices Act. They must promptly notify the client of any charges of noncompliance and remedy the situation at their own cost. The vendor is also accountable for any fines or penalties resulting from noncompliance. Additionally, the vendor must maintain all necessary controls, operations, and systems to enable the client to comply with its obligations.'

# %%
# response = query_engine.query("what are intellectual property rights of vendor?")
# Out:
# inside line 47 <llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine object at 0x7107199ae290>
# inside line 227
# inside line 229
# line 51
# line 53
# line 55
# line 189
# line 144
# inside line 227
# inside line 229
# line 228
# line 235
# line 240
# line 246
# line 252
# line 259
# line 146
# line 191
# inside line 227
# inside line 229
# line 196
# line 198 response Empty Response
# line 199
# line 58
# line 60

# %%
# print(str(response))
# Out:
# Empty Response
